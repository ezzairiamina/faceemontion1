# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/test\angry\10052.jpg
# 1         images/test\angry\10065.jpg
# 2         images/test\angry\10079.jpg
# 3         images/test\angry\10095.jpg
# 4         images/test\angry\10121.jpg
#                     ...
# 7061    images/test\surprise\9806.jpg
# 7062    images/test\surprise\9830.jpg
# 7063    images/test\surprise\9853.jpg
# 7064    images/test\surprise\9878.jpg
# 7065     images/test\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (11.1.0)

# %%
from PIL import Image

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\python.exe

# %%
# !pip show pillow
# Out:
# Name: pillow
# Version: 11.1.0
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.github.io
# Author:
# Author-email: "Jeffrey A. Clark" <aclark@aclark.net>
# License: MIT-CMU
# Location: C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires:
# Required-by:

# %%
import sys
# !{sys.executable} -m pip install --upgrade pillow
# Out:
# Requirement already satisfied: pillow in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (11.1.0)

# %%
from PIL import Image
print("Pillow is installed and working!")
# Out:
# Pillow is installed and working!

# %%
import PIL
print(PIL.__version__)
# Out:
# 11.1.0

# %%
def extract_features(images):
    features = []
    for image_path in tqdm(images):
        try:
            img = load_img(image_path, color_mode="grayscale")
            img = np.array(img)
            features.append(img)
        except Exception as e:
            print(f"Erreur avec l'image {image_path}: {e}")
    return features

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
import os

img_path = "images/train/angry/0.jpg"  # Mets un chemin valide ici
if os.path.exists(img_path):
    print("L'image existe")
else:
    print("L'image n'existe pas")
# Out:
# L'image existe

# %%
try:
    img = load_img(img_path)  # Remplace img_path par un chemin valide
    img.show()
except Exception as e:
    print(f"Erreur lors du chargement de l'image : {e}")
# Out:
# Erreur lors du chargement de l'image : Could not import PIL.Image. The use of `load_img` requires PIL.

# %%
import PIL
print(PIL.__version__)
# Out:
# 11.1.0

# %%
train_features = extract_features(train['image'])
# Out:
#  17%|██████████████████▋                                                                                         | 5001/28821 [00:00<00:00, 43550.06it/s]
# Erreur avec l'image images/train\angry\0.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10002.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10016.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10037.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10038.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10057.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10063.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10069.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10100.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10105.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10115.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10122.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10142.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1015.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10154.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10155.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10158.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1016.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10167.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10178.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1018.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10181.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10192.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10196.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10202.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10207.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10214.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10223.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10226.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10240.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10242.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10250.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10251.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10253.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10265.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10287.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10302.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10310.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10325.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10348.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10359.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10363.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10364.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10373.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10377.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10378.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10385.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10388.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1039.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10394.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10397.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10401.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10420.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10429.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10430.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10431.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10439.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10440.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10441.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10462.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10472.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10475.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10490.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10497.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1051.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10510.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10511.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10541.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10544.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10548.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10563.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10573.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10592.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10595.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10603.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10604.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1061.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10616.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10619.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10623.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10626.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10651.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10656.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1066.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10661.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10666.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10682.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10692.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\107.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10714.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10716.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10726.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10729.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10771.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10785.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10786.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10790.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10805.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10812.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10814.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10819.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10821.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10831.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10851.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10874.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10889.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10890.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10894.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1090.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10900.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10904.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10907.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10908.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10913.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10915.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10918.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10925.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10928.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10939.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10942.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10947.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10959.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10961.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10965.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10973.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1098.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10984.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10988.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10989.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\10994.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11004.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11008.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11011.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11014.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11018.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1102.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11042.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1105.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11053.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11060.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1108.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11083.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11102.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11109.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11113.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11117.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11118.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11151.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11153.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11174.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11181.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11190.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11205.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11206.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11215.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1122.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1123.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11235.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11258.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11267.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11268.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11274.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11286.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11289.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11301.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11315.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11325.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11377.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11379.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11385.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11386.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11389.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11403.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11410.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11411.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11420.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11426.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11432.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11449.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11458.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11460.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11464.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1147.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11474.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11475.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11480.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1150.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11534.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11537.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11545.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11548.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11550.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11557.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11571.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11572.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11577.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1158.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1160.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11606.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11607.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11617.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11623.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11641.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11644.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11645.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11647.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1166.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11669.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1168.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11688.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\117.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1170.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11707.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11708.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11714.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11732.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11735.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11744.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11755.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11756.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11759.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11764.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11769.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\1178.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\11781.jpg: Could not import PIL.Image. The use of `load_img` requires PIL.
# Erreur avec l'image images/train\angry\